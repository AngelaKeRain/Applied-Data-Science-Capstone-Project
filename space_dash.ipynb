# %%
# !pip install dash

# !pip install jupyter_dash

# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in e:\angela\anaconda\lib\site-packages (2.14.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in e:\angela\anaconda\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in e:\angela\anaconda\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in e:\angela\anaconda\lib\site-packages (from dash) (5.18.0)
# Requirement already satisfied: dash-html-components==2.0.0 in e:\angela\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in e:\angela\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in e:\angela\anaconda\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in e:\angela\anaconda\lib\site-packages (from dash) (4.7.1)
# Requirement already satisfied: requests in e:\angela\anaconda\lib\site-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in e:\angela\anaconda\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: ansi2html in e:\angela\anaconda\lib\site-packages (from dash) (1.9.1)
# Requirement already satisfied: nest-asyncio in e:\angela\anaconda\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: setuptools in e:\angela\anaconda\lib\site-packages (from dash) (68.0.0)
# Requirement already satisfied: importlib-metadata in e:\angela\anaconda\lib\site-packages (from dash) (6.0.0)
# Requirement already satisfied: Jinja2>=3.0 in e:\angela\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in e:\angela\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in e:\angela\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in e:\angela\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in e:\angela\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (23.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\angela\anaconda\lib\site-packages (from Werkzeug<3.1->dash) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in e:\angela\anaconda\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\angela\anaconda\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\angela\anaconda\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\angela\anaconda\lib\site-packages (from requests->dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in e:\angela\anaconda\lib\site-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in e:\angela\anaconda\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in e:\angela\anaconda\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: jupyter_dash in e:\angela\anaconda\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (2.14.2)
# Requirement already satisfied: requests in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (2.31.0)
# Requirement already satisfied: flask in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (2.2.2)
# Requirement already satisfied: retrying in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (8.15.0)
# Requirement already satisfied: ipykernel in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (6.25.0)
# Requirement already satisfied: ansi2html in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (1.9.1)
# Requirement already satisfied: nest-asyncio in e:\angela\anaconda\lib\site-packages (from jupyter_dash) (1.5.6)
# Requirement already satisfied: Werkzeug<3.1 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (5.18.0)
# Requirement already satisfied: dash-html-components==2.0.0 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (4.7.1)
# Requirement already satisfied: setuptools in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (68.0.0)
# Requirement already satisfied: importlib-metadata in e:\angela\anaconda\lib\site-packages (from dash->jupyter_dash) (6.0.0)
# Requirement already satisfied: Jinja2>=3.0 in e:\angela\anaconda\lib\site-packages (from flask->jupyter_dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in e:\angela\anaconda\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in e:\angela\anaconda\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: comm>=0.1.1 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: packaging in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (23.1)
# Requirement already satisfied: psutil in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in e:\angela\anaconda\lib\site-packages (from ipykernel->jupyter_dash) (5.7.1)
# Requirement already satisfied: backcall in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: decorator in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: pickleshare in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (2.15.1)
# Requirement already satisfied: stack-data in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: colorama in e:\angela\anaconda\lib\site-packages (from ipython->jupyter_dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\angela\anaconda\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\angela\anaconda\lib\site-packages (from requests->jupyter_dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\angela\anaconda\lib\site-packages (from requests->jupyter_dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in e:\angela\anaconda\lib\site-packages (from requests->jupyter_dash) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in e:\angela\anaconda\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in e:\angela\anaconda\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\angela\anaconda\lib\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.1.1)
# Requirement already satisfied: entrypoints in e:\angela\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\angela\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in e:\angela\anaconda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in e:\angela\anaconda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in e:\angela\anaconda\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.2.2)
# Requirement already satisfied: wcwidth in e:\angela\anaconda\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in e:\angela\anaconda\lib\site-packages (from importlib-metadata->dash->jupyter_dash) (3.11.0)
# Requirement already satisfied: executing in e:\angela\anaconda\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: asttokens in e:\angela\anaconda\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pure-eval in e:\angela\anaconda\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: plotly in e:\angela\anaconda\lib\site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in e:\angela\anaconda\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in e:\angela\anaconda\lib\site-packages (from plotly) (23.1)

# %%
import pandas as pd
import dash
from dash import html, dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update
import datetime as dt
from jupyter_dash import JupyterDash

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")

max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                             options=[{'label':'All Sites', 'value':'ALL'},
                                                      {'label':'CCAFS LC-40', 'value':'CCAFS LC-40'},
                                                      {'label':'VAFB SLC-4E', 'value':'VAFB SLC-4E'},
                                                      {'label':'KSC LC-39A', 'value':'KSC LC-39A'},
                                                      {'label':'CCAFS SLC-40', 'value':'CCAFS SLC-40'}],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min = 0,
                                                max = 10000,
                                                step = 1000,
                                                marks = {0: '0',
                                                         2500: '2500',
                                                         5000: '5000',
                                                         7500: '7500',
                                                         10000: '10000'},
                                                value = [min_payload, max_payload]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    if entered_site == 'ALL':
        filtered_df = spacex_df.groupby('Launch Site')['class'].sum().reset_index()
        fig = px.pie(filtered_df, 
                     values='class', 
                     names='Launch Site', 
                     title='Total Success Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]['class'].value_counts()
        fig = px.pie(filtered_df, 
                     values=filtered_df.values, 
                     names=filtered_df.index.map({1: 'Success', 0: 'Failure'}), 
                     title='Total Success Launches for Site ' + entered_site)
    return fig
    # return the outcomes piechart for a selected site
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'), Input(component_id="payload-slider", component_property="value")])
def update_scatter_plot(entered_site, payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0], payload[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df,
                         x = 'Payload Mass (kg)',
                         y = 'class',
                         color = 'Booster Version Category'
                         )
    else:
        fig = px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],
                         x = 'Payload Mass (kg)',
                         y = 'class',
                         color = 'Booster Version Category'
                         )
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='jupyterlab', port = 7001, dev_tools_ui=True, debug=True,dev_tools_hot_reload =True, threaded=True)
# Out:
# E:\Angela\ANACONDA\Lib\site-packages\dash\dash.py:538: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:7001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
